# %%
import pandas as pd
data = pd.read_csv('spotify_songs.csv')

# %%
dx = data.sample(10000)
dx
# Out:
#                      track_id  \
# 16472  0XeSTQIu2LqnAKdOigQUtT
# 6728   1AGeDbAlIcoJN01bLkFN82
# 4469   4BhXlLrlJSSA6b2LknHyBC
# 16814  06BrHnTVDOydsfg0LZ6mQb
# 11190  32Gk4O5K1xGfm0iEJKDvt3
# ...                       ...
# 30362  6NgwHmEgfQVIYQBq8QcWMi
# 20403  3TTragde5roTvwS2caAQOc
# 29269  2ZDOmcsZxEtwJ7cYeCoCkv
# 23877  3mau755ebHNf9B0qXAQXF9
# 10746  1C3PeqYtCFVFxUBdFZoxeT
#
#                                               track_name         track_artist  \
# 16472                   Clandestino (feat. Calypso Rose)            Manu Chao
# 6728                                            Gangland       Mankirt Aulakh
# 4469                                           Dead 2 Me         Emily Vaughn
# 16814                           Talk - Alle Farben Remix               Khalid
# 11190                               Rockstar on the Moon               Dr.ive
# ...                                                  ...                  ...
# ...

# %%
dx.to_csv('Spotify_music.csv', index = False)
